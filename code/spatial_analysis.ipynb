# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import json
import re
import nethelp as nh
import powerlaw
from collections import Counter
import community
import pickle
import graph_tool.all as gt

# %%
def extract_years(date_string):
    """
    Extracts start and end years from a string formatted as 'YYYY - YYYY'.

    This function looks for a date range in the format 'YYYY - YYYY' within the given string.
    If found, it extracts and returns the start year and end year as integers.

    Parameters
    ----------
    date_string : str
        The string that may contain a date range in the 'YYYY - YYYY' format.

    Returns
    -------
    tuple or None
        A tuple containing two integers: (start_year, end_year) if the pattern is found.
        Returns None if the pattern is not found.

    Examples
    --------
    >>> extract_years("Event happened between 1995 - 2000")
    (1995, 2000)

    >>> extract_years("No date here")
    None
    """
    # Define a regex pattern for 'YYYY - YYYY'
    pattern = r'(\d{4})\s*-\s*(\d{4})'
    
    # Search for the pattern in the input string
    match = re.search(pattern, date_string)
    
    if match:
        # Extract the start and end years from the match groups
        start_year = int(match.group(1))
        end_year = int(match.group(2))
        return start_year, end_year
    else:
        return None  # Return None if no match is found

# %%
def parse_training_data(link_attributes, institution, order):
    """
    Parses a list of educational or training attributes to extract relevant details such as 
    degree level, subject, start year, end year, and awards. The function handles various 
    formats and patterns in the input data and applies specific rules based on the presence 
    of keywords like 'residency', 'fellowship', and 'class of', and adjusts for special cases 
    such as osteopathic institutions ('DO' degrees).

    Parameters:
    -----------
    link_attributes : list of str
        A list containing details about an individual's training or education at a particular 
        institution. Each entry can represent degree level, subject, year range, or other details.
        
    institution : str
        The name of the institution where the training or education took place. This is 
        checked for keywords such as 'osteopath' to infer specific degree levels like 'DO'.
        
    order : int
        An integer representing the order of the training or education in the individual's 
        trajectory, used for tracking sequence in a graph or timeline.

    Returns:
    --------
    dict
        A dictionary with the following keys:
        - 'level' : str or None
            The training level or degree (e.g., 'MD', 'PhD', 'Fellowship', 'Residency').
        - 'order' : int
            The order of the training or education, as passed in the input.
        - 'subject' : str or None
            The subject or field of study (e.g., 'Biology', 'Cardiology').
        - 'start' : int or None
            The start year of the training/education.
        - 'end' : int or None
            The end year of the training/education.
        - 'award' : str or None
            Any awards or honors mentioned (e.g., 'Cum Laude', 'Honors').

    Example:
    --------
    >>> parse_training_data(['Fellowship', 'Cardiology', '2005 - 2007'], 'Harvard University', 1)
    {'level': 'fellowship', 'order': 1, 'subject': 'cardiology', 'start': 2005, 'end': 2007, 'award': None}

    >>> parse_training_data(['Class of 2005'], 'NYIT College Of Osteopathic Medicine', 2)
    {'level': 'do', 'order': 2, 'subject': None, 'start': 2001, 'end': 2005, 'award': None}
    """
    level = None
    subject = None
    start_date = None
    end_date = None
    award = None 
    
    l = -1
    for entry in link_attributes:
        
        # training level 
        l = l + 1
        result = extract_years(entry)
        if 'class of' in entry.lower():
            level = 'md'
            # topic = None
            start_date = int(entry.split()[-1]) - 4
            end_date = int(entry.split()[-1])

        elif l == 0:

            if 'residency' in entry.lower():
                level = 'residency' 
                # start = start = int(entry.split()[-3]) # this needs to be its own if clause becuase the date is not going to be in the same entry as residency
                
            elif 'postdoc' in entry.lower().replace('-', ''):
                level = 'postdoc'
            
            elif 'fellowship' in entry.lower(): 
                level = 'fellowship'
            
            elif 'intern' in entry.lower():
                level = 'internship'

            elif 'intern' in entry.lower():
                level = 'internship'

            elif 'phd' in entry.lower().replace('.', ''):
                level = 'phd'

            elif 'mph' in entry.lower().replace('.', ''):
                level = 'mph'

            elif 'ba' in entry.lower().replace('.', ''):
                level = 'ba'
            
            elif 'bs' in entry.lower().replace('.', ''):
                level = 'bs'
            
            else:
                level = entry.lower().replace('.','')
        
        elif 'do' == entry.lower().replace('.',''):
            level = 'do'
        # start and end dates
        elif result:
            start_date, end_date = result
        
        # awards
        elif 'cum' in entry.lower():
            award = entry.lower()
        elif 'honor' in entry.lower() or 'honour' in entry.lower():
            award = entry.lower()

        # assume anything else is subject 
        else:
            subject = entry.lower()

    if 'osteopath' in institution.lower():
        level = 'do'
        
    parsed_dict = {
        'level': level,
        'order': order,
        'subject': subject,
        'start': start_date,
        'end': end_date,
        'award': award
    }
    return parsed_dict

# %%
i = 2
filepath = f'../../physician_trajectories/data/card/{i}.json'
with open(filepath, 'r') as f:
    data = json.load(f) 
state =data[str(i)]['office'].split()[-2]
zipcode = data[str(i)]['office'].split()[-1]
print(state,zipcode)
# Out:
# MN 55905

# %%
training_data = data[str(i)]['training']
[list(item.keys())[0] for item in training_data.values()]
# Out:
# ['University of Missouri-Kansas City School of Medicine',
#  'University of Missouri-Kansas City School of Medicine',
#  'Mayo Clinic College of Medicine and Science (Rochester) A Aerospace Medicine',
#  'University of Missouri-Kansas City School of Medicine',
#  'University of Colorado School of Medicine Anschutz Medical Campus',
#  'Mayo Clinic College of Medicine',
#  'Zagazig University Faculty of Medicine']

# %%
import os
import json
import pandas as pd

base_path = '../../physician_trajectories/data'
folders = [folder for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, folder))]

errors = 0
# tdf_dict = {}  # Dictionary to store tdf for each folder

ids = []
states = []
zipcodes = []
specialties = []
institutions = []

for folder in folders:
    folder_path = os.path.join(base_path, folder)
    sdf = pd.DataFrame({'doctor_id': [], 'state': [], 'zipcode': [], 'specialty': [], 'institutions': []})
    print(f"Processing folder: {folder}")
    
    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json') and 'failed' not in file_name and 'next' not in file_name:
            try:
                file_path = os.path.join(folder_path, file_name)
                with open(file_path, 'r') as f:
                    data = json.load(f)
                
                # Assuming the file name format includes the ID
                i = int(file_name.split('.')[0])
                
                id = i
                state = data[str(i)]['office'].split()[-2]
                zipcode = data[str(i)]['office'].split()[-1]
                specialty = data[str(i)]['specialty']
                institution = [list(item.keys())[0] for item in data[str(i)]['training'].values()]
                if state and zipcode and specialty and institution and id:
                    unique_id = f"{id}_{folder}"
                    ids.append(unique_id)
                    states.append(state)
                    zipcodes.append(zipcode)
                    specialties.append(specialty)
                    institutions.append(institution)
                
            except Exception as e:
                print(f"[Error] Error processing file {file_name} in folder {folder}: {e}")
                errors += 1
                continue
    

    #tdf_dict[folder] = tdf  # Store the tdf for this folder
    print(f"Completed processing folder: {folder}.")

sdf = pd.DataFrame({'doctor_id': ids, 'state': states, 'zipcode': zipcodes, 'specialty': specialties, 'institutions': institutions})   

# Example: Access the tdf for a specific folder
# print(tdf_dict['card'])
# Out:
# Processing folder: neurosurgery
# [Error] Error processing file 4267.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 791.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3609.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2761.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8442.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 343.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 355.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 617.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4070.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2632.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2350.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5303.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2612.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5207.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3557.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6112.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1911.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2844.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1785.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2795.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8265.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2384.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5251.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6241.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8571.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2310.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1183.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2869.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2185.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7387.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 636.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 266.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2756.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1859.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1674.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8455.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3171.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6373.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3018.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5066.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8357.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2648.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6522.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 682.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7338.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5094.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7553.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8425.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8126.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7729.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3382.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 826.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8798.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5391.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6102.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7621.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4261.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2474.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2024.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5348.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2065.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5466.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8805.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 742.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4575.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3930.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3526.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5722.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3927.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2009.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2662.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2398.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3566.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4935.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1074.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5467.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6162.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5430.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 295.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6135.json in folder neurosurgery: 'NoneType' object has no attribute 'split'
# [Error] Error processing file 4237.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6089.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6748.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 811.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2140.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1916.json in folder neurosurgery: 'NoneType' object has no attribute 'split'
# [Error] Error processing file 4702.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6752.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3803.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6139.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6093.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6355.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 919.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3638.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 372.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7339.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5168.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7341.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5239.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5055.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6141.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 577.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5917.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6638.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7880.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6116.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4202.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1000.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3292.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3504.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1169.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1606.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6985.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5700.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1201.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 721.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6458.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7320.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4672.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4664.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4799.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5188.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4798.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5473.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3909.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1467.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4720.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4370.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1172.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1471.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3227.json in folder neurosurgery: 'NoneType' object has no attribute 'split'
# [Error] Error processing file 8892.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8312.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8105.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5760.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8144.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8847.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7874.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6253.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3456.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 798.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6357.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1703.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6506.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6156.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6101.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3246.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3534.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3308.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 357.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8505.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2431.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7371.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 843.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 286.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 5024.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1067.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4496.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1417.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8899.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4013.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6887.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6995.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7957.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2606.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2885.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2493.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1179.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6487.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8860.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4843.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8163.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7500.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7917.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3542.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 7628.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6890.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8565.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2492.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2742.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1617.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 622.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6428.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4550.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4784.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4442.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2294.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1791.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2040.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 659.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6150.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 2847.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4090.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6598.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 1932.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3149.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 679.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8178.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 3348.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 6633.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 8512.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 4024.json in folder neurosurgery: string indices must be integers, not 'str'
# [Error] Error processing file 839.json in folder neurosurgery: string indices must be integers, not 'str'
# Completed processing folder: neurosurgery.
# Processing folder: medical_genetics
# [Error] Error processing file 3721.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2833.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3371.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 683.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 379.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2130.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2075.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1659.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2976.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1209.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 115.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1435.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3408.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 400.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1966.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2649.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2219.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2537.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2167.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3326.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2864.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 284.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3263.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 791.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2921.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2472.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2188.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2022.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1527.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 512.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1874.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1198.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1462.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2872.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3760.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 768.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3330.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 338.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2464.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2937.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1618.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1248.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3275.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 857.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1862.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1161.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1531.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3019.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1024.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2608.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 912.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2258.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 695.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2825.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3737.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 380.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2960.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1566.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 553.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1136.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 103.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1835.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 800.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 416.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1423.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1589.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1073.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1264.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 251.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3609.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 601.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2448.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2018.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1321.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 744.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1771.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 894.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2274.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2624.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 197.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3465.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1458.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1008.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 482.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3170.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2331.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2761.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3873.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 656.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 206.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1233.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2809.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 590.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2673.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 98.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2389.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2223.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3824.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1819.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 77.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2366.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1225.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 210.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3648.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1675.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2409.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2059.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 355.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1730.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2235.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2665.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3424.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1049.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 586.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 990.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3832.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 617.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1622.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1788.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 247.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1767.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1337.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3473.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2632.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2262.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 882.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3865.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2777.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 36.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3166.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3536.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1086.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3111.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 119.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2350.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 41.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2645.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1439.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1069.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2096.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2995.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1340.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1710.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1205.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 230.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1655.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3668.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3392.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 660.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2079.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3845.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1878.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2757.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2307.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1481.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3146.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3516.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3003.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3453.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1194.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1897.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 288.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2868.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 772.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1317.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 322.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2491.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 637.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2887.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 267.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1252.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3500.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 508.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3150.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1497.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 158.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2311.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2741.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2254.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1182.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1478.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3015.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2487.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 334.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1301.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 764.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1751.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3279.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1244.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 271.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3629.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1614.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 621.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2192.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2038.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2716.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3107.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1090.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3042.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1585.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3412.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2653.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2829.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1706.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 733.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 699.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 363.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3691.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2080.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 676.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3384.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 226.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1454.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3469.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3193.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1907.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 932.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2278.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2782.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2297.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1842.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 174.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3486.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1141.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 524.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2014.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2444.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2917.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1638.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1287.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 3310.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 318.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 2151.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 94.json in folder medical_genetics: string indices must be integers, not 'str'
# [Error] Error processing file 1950.json in folder medical_genetics: string indices must be integers, not 'str'
# ...
# [Error] Error processing file 141.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 2934.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 291.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 442.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 157.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 1162.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 507.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 229.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 383.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 415.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 58.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 550.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 100.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 317.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 252.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 602.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 23.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 481.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 194.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 340.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 205.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 74.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 593.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 439.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 356.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 213.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 62.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 585.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 9.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 301.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 614.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 244.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 497.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 35.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 182.json in folder psychiatry: string indices must be integers, not 'str'
# [Error] Error processing file 478.json in folder psychiatry: string indices must be integers, not 'str'
# Completed processing folder: psychiatry.
# Processing folder: hematology
# [Error] Error processing file 1823.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2219.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 142.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1874.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 154.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2258.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 103.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2223.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 640.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 569.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1340.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2429.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1301.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2468.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 318.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1053.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2690.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2540.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1855.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1382.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 83.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1642.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1479.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1029.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 773.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1603.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2756.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2428.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1592.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1859.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2234.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2737.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1818.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1926.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 293.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1199.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 544.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2424.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2585.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1311.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 735.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1645.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2157.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1956.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2395.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1937.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1649.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 555.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 353.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1736.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 996.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1018.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2265.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 89.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 344.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1799.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1561.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 368.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2571.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1023.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 446.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2526.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 954.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1961.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2072.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 923.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1900.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 364.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1644.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 50.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1756.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1613.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 775.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1486.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1469.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2513.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 536.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1391.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 259.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2753.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 351.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2227.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1667.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1630.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 691.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 280.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 940.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1650.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1938.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 366.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1282.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 599.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 130.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1369.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1017.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 480.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1266.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 843.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1175.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2684.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 96.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1905.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2082.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2344.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 623.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1753.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2240.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2580.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1586.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 730.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 462.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1050.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 531.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2758.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 2060.json in folder hematology: string indices must be integers, not 'str'
# [Error] Error processing file 1699.json in folder hematology: string indices must be integers, not 'str'
# Completed processing folder: hematology.

# %%
sdf
# Out:
#                 doctor_id state zipcode     specialty  \
# 0       3721_neurosurgery    CA   93301  Neurosurgery
# 1       2833_neurosurgery    WA   98101  Neurosurgery
# 2        729_neurosurgery    OK   73104  Neurosurgery
# 3       6523_neurosurgery    FL   32611  Neurosurgery
# 4       6489_neurosurgery    CA   93291  Neurosurgery
# ...                   ...   ...     ...           ...
# 205985    2631_hematology    CA   91316    Hematology
# 205986    2261_hematology    KS   66205    Hematology
# 205987     881_hematology    OR   97239    Hematology
# 205988     182_hematology    IL   60611    Hematology
# 205989     478_hematology    KY   40536    Hematology
#
#                                              institutions
# 0       [National Capital Consortium, National Capital...
# 1       [University of Washington, University of Texas...
# 2       [University of California (San Francisco) Scho...
# 3             [University of Florida College of Medicine]
# 4       [University of Miami/Jackson Health System, UC...
# ...                                                   ...
# 205985                                            [Other]
# 205986  [Vidant Medical Center/East Carolina Universit...
# 205987  [Brigham and Women's Hospital/Massachusetts Ge...
# 205988  [McGaw Medical Center of Northwestern Universi...
# 205989  [Stanford University, Westchester Medical Cent...
#
# [205990 rows x 5 columns]

# %%
Counter(sdf['specialty'])
# Out:
# Counter({'Obstetrics & Gynecology': 57954,
#          'Cardiology': 38337,
#          'Ophthalmology': 25567,
#          'Gastroenterology': 21538,
#          'Dermatology': 18181,
#          'Geriatrics': 10923,
#          'Neurosurgery': 8718,
#          'Allergy & Immunology': 6238,
#          'Psychiatry': 4933,
#          'Interventional Radiology': 3642,
#          'Child Neurology': 2909,
#          'Colon & Rectal Surgery': 2812,
#          'Hematology': 2664,
#          'Medical Genetics': 1529,
#          'Endocrinology': 27,
#          'Internal Medicine': 7,
#          'Other MD/DO': 5,
#          'Resident Physician': 4,
#          'Pediatric Endocrinology': 1,
#          'Emergency Medicine': 1})

# %%
Counter(sdf['state'])
# Out:
# Counter({'CA': 24324,
#          'NY': 18189,
#          'TX': 14400,
#          'FL': 13556,
#          'PA': 10062,
#          'IL': 8136,
#          'OH': 7226,
#          'MA': 7105,
#          'NJ': 6526,
#          'NC': 6396,
#          'MI': 6198,
#          'GA': 5356,
#          'VA': 5230,
#          'MD': 5059,
#          'WA': 4352,
#          'MN': 3881,
#          'TN': 3867,
#          'MO': 3692,
#          'AZ': 3685,
#          'CO': 3558,
#          'IN': 3403,
#          'WI': 3378,
#          'CT': 3284,
#          'LA': 2710,
#          'OR': 2657,
#          'SC': 2634,
#          'AL': 2234,
#          'KY': 2218,
#          'OK': 1637,
#          'UT': 1523,
#          'PR': 1427,
#          'IA': 1389,
#          'KS': 1359,
#          'AR': 1344,
#          'DC': 1301,
#          'NV': 1242,
#          'MS': 1215,
#          'HI': 981,
#          'NM': 970,
#          'NE': 969,
#          'WV': 952,
#          'NH': 921,
#          'RI': 914,
#          'ME': 837,
#          'ID': 679,
#          'DE': 601,
#          'MT': 549,
#          'SD': 441,
#          'VT': 408,
#          'ND': 356,
#          'AK': 327,
#          'WY': 187,
#          'GU': 38,
#          'VI': 35,
#          'AE': 28,
#          'AP': 22,
#          'MP': 8,
#          'Medical': 2,
#          'of': 2,
#          'Albuquerque,': 1,
#          'Coll': 1,
#          'Medicine': 1,
#          'Houston,': 1,
#          'Fort': 1,
#          'St.Victory': 1,
#          'Kyoto': 1,
#          'Louis,': 1,
#          'Jose,': 1,
#          'AS': 1})

# %%
Counter(sdf['zipcode'])
# Out:
# Counter({'77030': 1451,
#          '55905': 888,
#          '02115': 882,
#          '02114': 864,
#          '19104': 853,
#          '10016': 809,
#          '60611': 759,
#          '60612': 719,
#          '44195': 704,
#          '10029': 675,
#          '10032': 577,
#          '80045': 567,
#          '15213': 559,
#          '90095': 551,
#          '19107': 547,
#          '75390': 544,
#          '10021': 542,
#          '78229': 537,
#          '94305': 527,
#          '46202': 519,
#          '21287': 515,
#          '48109': 508,
#          '63110': 468,
#          '33136': 463,
#          '97239': 459,
#          '37232': 454,
#          '02215': 445,
#          '10065': 435,
#          '72205': 432,
#          '94143': 409,
#          '53226': 409,
#          '92868': 399,
#          '92037': 398,
#          '90048': 386,
#          '92103': 383,
#          '52242': 372,
#          '90033': 372,
#          '30322': 369,
#          '06510': 367,
#          '76104': 363,
#          '35233': 355,
#          '94115': 353,
#          '44106': 351,
#          '20010': 326,
#          '10467': 322,
#          '60637': 319,
#          '95817': 318,
#          '37203': 318,
#          '98195': 316,
#          '90027': 310,
#          '02118': 310,
#          '98104': 309,
#          '48202': 306,
#          '30342': 306,
#          '27514': 304,
#          '27705': 299,
#          '43210': 287,
#          '17033': 287,
#          '94304': 286,
#          '84132': 284,
#          '63141': 283,
#          '29425': 273,
#          '10019': 273,
#          '21201': 268,
#          '32806': 267,
#          '14642': 266,
#          '40202': 264,
#          '10461': 262,
#          '45219': 258,
#          '92354': 254,
#          '27710': 252,
#          '02111': 250,
#          '55455': 250,
#          '10022': 250,
#          '27103': 247,
#          '73104': 246,
#          '48201': 244,
#          '39216': 237,
#          '29605': 236,
#          '20037': 236,
#          '11042': 236,
#          '75231': 235,
#          '70112': 234,
#          '98405': 234,
#          '28204': 232,
#          '96813': 227,
#          '90404': 226,
#          '92123': 226,
#          '32224': 225,
#          '10003': 224,
#          '11030': 222,
#          '07960': 221,
#          '23298': 214,
#          '22031': 209,
#          '27157': 209,
#          '21204': 209,
#          '33612': 207,
#          '46260': 205,
#          '55435': 205,
#          '75093': 204,
#          '32610': 203,
#          '11203': 203,
#          '19140': 202,
#          '14221': 202,
#          '97225': 201,
#          '27607': 201,
#          '30309': 200,
#          '49503': 199,
#          '06106': 198,
#          '01605': 197,
#          '40207': 196,
#          '95128': 196,
#          '27834': 195,
#          '66160': 194,
#          '15212': 194,
#          '30060': 194,
#          '60153': 193,
#          '03756': 193,
#          '08901': 192,
#          '10028': 192,
#          '33606': 190,
#          '07601': 189,
#          '93720': 188,
#          '95661': 187,
#          '10075': 187,
#          '22908': 187,
#          '85259': 187,
#          '76508': 187,
#          '13210': 187,
#          '75246': 187,
#          '78705': 184,
#          '85016': 183,
#          '99508': 181,
#          '20850': 181,
#          '95051': 181,
#          '53792': 180,
#          '40536': 180,
#          '70121': 180,
#          '33021': 179,
#          '48073': 179,
#          '33176': 178,
#          '02903': 178,
#          '35801': 178,
#          '11021': 177,
#          '99204': 177,
#          '48105': 175,
#          '95816': 174,
#          '85006': 173,
#          '21401': 173,
#          '29203': 171,
#          '01805': 171,
#          '98004': 171,
#          '92120': 171,
#          '87106': 170,
#          '92335': 170,
#          '48197': 170,
#          '10128': 169,
#          '21224': 167,
#          '94598': 167,
#          '28803': 166,
#          '91105': 164,
#          '08043': 164,
#          '12208': 161,
#          '20007': 159,
#          '01655': 159,
#          '44109': 159,
#          '53215': 159,
#          '18103': 158,
#          '45242': 157,
#          '30912': 156,
#          '22042': 156,
#          '43214': 156,
#          '94611': 156,
#          '11501': 156,
#          '77555': 155,
#          '17822': 155,
#          '30501': 155,
#          '02905': 155,
#          '94040': 154,
#          '33143': 153,
#          '26506': 153,
#          '17601': 153,
#          '70115': 152,
#          '34239': 152,
#          '38138': 152,
#          '19713': 151,
#          '05401': 149,
#          '32308': 149,
#          '54601': 149,
#          '77054': 148,
#          '53715': 147,
#          '11219': 147,
#          '84107': 147,
#          '38120': 146,
#          '19096': 146,
#          '77024': 145,
#          '92663': 145,
#          '20889': 145,
#          '62702': 144,
#          '04102': 143,
#          '57105': 143,
#          '11530': 143,
#          '94538': 142,
#          '08103': 141,
#          '85712': 141,
#          '95825': 140,
#          '92660': 140,
#          '06519': 139,
#          '60068': 139,
#          '78258': 139,
#          '78234': 139,
#          '70808': 139,
#          '90505': 138,
#          '94110': 138,
#          '94109': 138,
#          '87109': 138,
#          '55407': 137,
#          '90211': 137,
#          '98101': 136,
#          '90089': 136,
#          '90210': 136,
#          '11733': 136,
#          '11201': 136,
#          '29607': 136,
#          '33607': 135,
#          '75230': 135,
#          '46032': 134,
#          '11355': 134,
#          '22903': 134,
#          '60657': 134,
#          '17403': 134,
#          '45229': 133,
#          '68198': 132,
#          '37920': 132,
#          '65212': 132,
#          '64108': 132,
#          '15224': 132,
#          '28207': 132,
#          '71103': 131,
#          '11794': 130,
#          '06030': 130,
#          '73120': 130,
#          '63108': 130,
#          '32803': 129,
#          '37604': 128,
#          '60540': 128,
#          '30033': 128,
#          '06810': 127,
#          '97504': 127,
#          '35209': 127,
#          '63017': 126,
#          '85013': 126,
#          '27609': 126,
#          '11215': 126,
#          '75235': 125,
#          '10013': 125,
#          '64111': 124,
#          '98201': 123,
#          '65201': 123,
#          '19141': 123,
#          '60201': 123,
#          '20892': 123,
#          '18104': 123,
#          '33511': 122,
#          '74136': 122,
#          '48124': 122,
#          '33410': 122,
#          '30303': 122,
#          '53705': 122,
#          '60453': 121,
#          '98105': 121,
#          '32216': 121,
#          '01107': 120,
#          '77598': 120,
#          '20815': 120,
#          '68114': 120,
#          '33140': 120,
#          '44122': 120,
#          '10017': 119,
#          '92653': 119,
#          '97210': 118,
#          '73112': 118,
#          '32207': 118,
#          '75701': 118,
#          '11209': 117,
#          '77479': 116,
#          '33308': 116,
#          '11235': 116,
#          '92505': 115,
#          '85258': 115,
#          '80124': 114,
#          '21093': 114,
#          '20852': 113,
#          '23507': 113,
#          '65804': 113,
#          '04401': 113,
#          '46845': 113,
#          '07103': 113,
#          '28401': 113,
#          '98034': 113,
#          '41017': 112,
#          '50266': 112,
#          '32901': 111,
#          '27401': 111,
#          '20817': 111,
#          '79902': 110,
#          '77401': 110,
#          '93003': 110,
#          '80205': 110,
#          '18015': 110,
#          '11220': 110,
#          '98122': 109,
#          '59101': 109,
#          '35205': 109,
#          '38103': 109,
#          '70006': 109,
#          '12601': 109,
#          '33613': 109,
#          '33173': 109,
#          '49546': 108,
#          '28304': 108,
#          '97401': 108,
#          '92708': 108,
#          '33701': 107,
#          '94609': 107,
#          '32209': 106,
#          '10595': 106,
#          '92691': 106,
#          '96814': 106,
#          '85224': 105,
#          '31201': 105,
#          '92618': 105,
#          '07631': 105,
#          '19610': 105,
#          '07052': 105,
#          '32605': 105,
#          '23502': 105,
#          '03301': 105,
#          '37660': 104,
#          '33331': 104,
#          '24014': 104,
#          '30046': 104,
#          '77074': 104,
#          '11375': 104,
#          '92807': 103,
#          '36608': 103,
#          '06606': 103,
#          '78758': 103,
#          '28211': 102,
#          '14203': 102,
#          '06511': 102,
#          '00921': 102,
#          '23229': 102,
#          '45220': 102,
#          '33908': 102,
#          '11040': 102,
#          '06105': 101,
#          '00918': 101,
#          '30606': 101,
#          '90502': 101,
#          '91402': 101,
#          '95210': 101,
#          '07470': 100,
#          '92134': 100,
#          '25701': 100,
#          '49525': 100,
#          '23235': 100,
#          '27599': 100,
#          '89128': 100,
#          '98664': 99,
#          '63128': 99,
#          '55805': 99,
#          '28025': 99,
#          '90503': 99,
#          '89502': 99,
#          '37421': 99,
#          '30328': 99,
#          '95403': 99,
#          '28210': 99,
#          '55433': 98,
#          '32960': 98,
#          '63104': 98,
#          '20814': 98,
#          '95823': 98,
#          '92270': 97,
#          '84604': 97,
#          '97701': 97,
#          '07039': 97,
#          '22401': 97,
#          '63117': 97,
#          '10457': 97,
#          '68124': 96,
#          '10305': 96,
#          '10025': 96,
#          '22601': 96,
#          '72703': 96,
#          '10549': 96,
#          '34102': 96,
#          '60126': 96,
#          '10024': 96,
#          '33756': 95,
#          '31405': 95,
#          '91367': 95,
#          '11373': 95,
#          '34471': 95,
#          '19047': 95,
#          '39232': 95,
#          '80204': 95,
#          '32204': 95,
#          '14620': 95,
#          '89106': 95,
#          '48307': 95,
#          '61801': 94,
#          '74104': 94,
#          '29169': 94,
#          '11706': 94,
#          '92121': 94,
#          '30308': 94,
#          '63131': 94,
#          '43205': 94,
#          '20060': 94,
#          '11570': 93,
#          '32804': 93,
#          '43221': 93,
#          '79106': 93,
#          '60521': 92,
#          '04074': 92,
#          '93105': 92,
#          '65807': 92,
#          '46804': 92,
#          '85206': 92,
#          '33180': 92,
#          '32504': 91,
#          '97227': 91,
#          '07450': 91,
#          '48912': 91,
#          '02467': 91,
#          '45409': 90,
#          '60005': 90,
#          '57701': 90,
#          '90806': 90,
#          '07753': 90,
#          '40503': 90,
#          '77070': 90,
#          '14618': 90,
#          '93940': 90,
#          '92024': 90,
#          '77380': 90,
#          '94010': 90,
#          '19010': 90,
#          '23226': 90,
#          '11795': 89,
#          '14621': 89,
#          '70508': 89,
#          '98112': 89,
#          '98133': 89,
#          '76712': 89,
#          '66211': 89,
#          '11743': 89,
#          '70433': 88,
#          '02481': 88,
#          '46321': 88,
#          '54449': 88,
#          '08755': 88,
#          '78731': 88,
#          '20016': 88,
#          '94063': 87,
#          '08540': 87,
#          '37403': 87,
#          '55416': 87,
#          '06902': 87,
#          '60026': 87,
#          '98686': 87,
#          '44124': 86,
#          '44145': 86,
#          '32608': 86,
#          '33805': 86,
#          '77025': 86,
#          '30901': 86,
#          '93301': 85,
#          '33486': 85,
#          '35243': 85,
#          '56303': 85,
#          '91505': 85,
#          '80907': 85,
#          '97015': 85,
#          '11354': 85,
#          '07652': 85,
#          '92093': 85,
#          '37205': 85,
#          '90706': 85,
#          '19046': 85,
#          '28801': 85,
#          '80026': 84,
#          '46256': 84,
#          '58103': 84,
#          '19611': 84,
#          '94301': 84,
#          '85724': 84,
#          '98801': 84,
#          '94158': 84,
#          '21044': 84,
#          '23454': 84,
#          '20176': 83,
#          '08820': 83,
#          '08816': 83,
#          '10023': 83,
#          '80218': 83,
#          '37129': 83,
#          '78207': 83,
#          '10010': 83,
#          '02138': 83,
#          '80220': 83,
#          '23606': 83,
#          '94589': 83,
#          '29464': 82,
#          '06708': 82,
#          '45429': 82,
#          '97213': 82,
#          '29414': 82,
#          '91436': 82,
#          '98506': 82,
#          '70809': 82,
#          '07728': 82,
#          '33324': 82,
#          '96826': 82,
#          '10011': 82,
#          '33458': 82,
#          '15219': 81,
#          '21237': 81,
#          '37404': 81,
#          '21061': 81,
#          '48075': 81,
#          '23320': 81,
#          '33484': 81,
#          '10583': 81,
#          '91356': 81,
#          '95032': 81,
#          '31904': 81,
#          '15146': 80,
#          '33907': 79,
#          '83814': 79,
#          '91942': 79,
#          '14626': 79,
#          '95119': 79,
#          '02904': 79,
#          '55125': 79,
#          '98055': 78,
#          '91010': 78,
#          '74133': 78,
#          '28602': 78,
#          '11787': 78,
#          '84403': 77,
#          '07666': 77,
#          '19106': 77,
#          '75024': 77,
#          '27704': 77,
#          '55415': 77,
#          '22033': 77,
#          '47630': 77,
#          '40509': 77,
#          '34741': 77,
#          '27408': 76,
#          '83704': 76,
#          '55102': 76,
#          '33462': 76,
#          '55454': 76,
#          '27518': 76,
#          '90710': 76,
#          '48034': 75,
#          '79410': 75,
#          '26505': 75,
#          '92835': 75,
#          '55426': 75,
#          '89148': 75,
#          '80206': 75,
#          '27517': 75,
#          '11229': 75,
#          '90034': 75,
#          '48322': 74,
#          '75034': 74,
#          '15232': 74,
#          '10001': 74,
#          '80113': 74,
#          '43081': 74,
#          '89052': 74,
#          '97330': 74,
#          '93701': 74,
#          '89511': 74,
#          '61614': 74,
#          '48334': 74,
#          '18901': 74,
#          '98109': 74,
#          '28054': 73,
#          '49684': 73,
#          '72401': 73,
#          '87131': 73,
#          '38104': 73,
#          '77384': 73,
#          '44304': 73,
#          '57108': 73,
#          '91706': 73,
#          '70817': 73,
#          '97477': 72,
#          '23708': 72,
#          '38801': 72,
#          '14623': 72,
#          '53188': 72,
#          '78212': 72,
#          '66215': 72,
#          '94596': 72,
#          '46290': 72,
#          '95124': 71,
#          '28374': 71,
#          '87505': 71,
#          '98431': 71,
#          '19380': 71,
#          '80909': 71,
#          '95355': 71,
#          '33133': 71,
#          '55369': 71,
#          '19063': 71,
#          '33125': 70,
#          '19001': 70,
#          '10532': 70,
#          '78665': 70,
#          '33028': 70,
#          '98225': 70,
#          '79905': 70,
#          '96817': 70,
#          '06032': 70,
#          '10451': 70,
#          '46237': 70,
#          '28403': 70,
#          '48038': 69,
#          '70503': 69,
#          '43215': 69,
#          '47905': 69,
#          '60123': 69,
#          '85012': 69,
#          '76132': 69,
#          '61107': 69,
#          '94025': 69,
#          '02130': 68,
#          '33609': 68,
#          '59901': 68,
#          '02446': 68,
#          '08053': 68,
#          '43623': 68,
#          '60515': 68,
#          '85381': 68,
#          '32503': 68,
#          '93454': 68,
#          '60010': 68,
#          '54301': 68,
#          '78745': 68,
#          '32256': 68,
#          '21208': 68,
#          '30214': 68,
#          '02445': 68,
#          '48093': 68,
#          '02462': 67,
#          '64804': 67,
#          '83712': 67,
#          '21702': 67,
#          '32827': 67,
#          '80012': 67,
#          '85251': 67,
#          '85260': 67,
#          '94118': 67,
#          '95926': 67,
#          '94705': 67,
#          '32792': 67,
#          '77004': 67,
#          '36604': 66,
#          '00725': 66,
#          '60190': 66,
#          '90017': 66,
#          '76012': 66,
#          '02886': 66,
#          '94553': 66,
#          '78759': 66,
#          '68506': 66,
#          '60016': 66,
#          '33156': 65,
#          '97301': 65,
#          '39202': 65,
#          '38119': 65,
#          '96001': 65,
#          '83404': 65,
#          '60076': 65,
#          '30281': 65,
#          '00680': 65,
#          '27610': 65,
#          '60169': 65,
#          '93401': 64,
#          '91361': 64,
#          '68131': 64,
#          '67214': 64,
#          '06360': 64,
#          '29303': 64,
#          '58501': 64,
#          '37067': 64,
#          '48439': 64,
#          '08724': 64,
#          '47403': 64,
#          '84124': 64,
#          '11432': 64,
#          '01199': 64,
#          '33065': 64,
#          '27713': 64,
#          '79430': 64,
#          '91342': 64,
#          '53717': 64,
#          '02135': 63,
#          '30329': 63,
#          '37916': 63,
#          '11554': 63,
#          '24016': 63,
#          '93534': 63,
#          '16507': 63,
#          '78539': 63,
#          '20910': 63,
#          '32405': 63,
#          '97062': 63,
#          '33401': 63,
#          '21804': 63,
#          '92506': 63,
#          '08822': 63,
#          '01970': 63,
#          '96793': 63,
#          '94121': 63,
#          '01915': 63,
#          '43213': 63,
#          '94903': 63,
#          '91786': 63,
#          '78613': 63,
#          '94558': 63,
#          '40504': 62,
#          '55101': 62,
#          '90025': 62,
#          '13326': 62,
#          '30005': 62,
#          '78503': 62,
#          '85032': 62,
#          '75075': 62,
#          '30097': 62,
#          '60608': 62,
#          '29615': 62,
#          '94588': 62,
#          '80120': 62,
#          '77478': 62,
#          '46601': 61,
#          '91355': 61,
#          '96819': 61,
#          '27262': 61,
#          '97216': 61,
#          '43212': 61,
#          '08873': 61,
#          '02360': 61,
#          '60622': 61,
#          '08648': 61,
#          '33316': 61,
#          '17603': 61,
#          '94015': 61,
#          '11576': 61,
#          '20036': 61,
#          '92130': 61,
#          '01608': 61,
#          '78215': 61,
#          '33134': 61,
#          '25304': 61,
#          '22304': 61,
#          '17011': 60,
#          '50314': 60,
#          '20190': 60,
#          '95350': 60,
#          '11418': 60,
#          '92262': 60,
#          '84790': 60,
#          '66606': 60,
#          '99352': 60,
#          '22911': 60,
#          '29621': 60,
#          '32751': 60,
#          '00917': 60,
#          '78681': 60,
#          '44718': 60,
#          '95065': 60,
#          '28203': 59,
#          '02190': 59,
#          '02747': 59,
#          '85718': 59,
#          '85710': 59,
#          '40508': 59,
#          '60631': 59,
#          '17042': 59,
#          '30909': 59,
#          '56001': 59,
#          '19111': 59,
#          '29204': 59,
#          '55114': 59,
#          '22205': 58,
#          '94904': 58,
#          '54701': 58,
#          '55404': 58,
#          '03801': 58,
#          '24153': 58,
#          '54311': 58,
#          '48823': 58,
#          '02601': 58,
#          '10701': 58,
#          '67226': 58,
#          '33016': 58,
#          '02139': 58,
#          '66204': 58,
#          '48602': 58,
#          '91360': 58,
#          '03110': 58,
#          '39402': 58,
#          '95356': 58,
#          '06830': 58,
#          '60625': 58,
#          '29732': 58,
#          '08057': 58,
#          '31404': 58,
#          '10012': 58,
#          '93291': 57,
#          '45069': 57,
#          '32114': 57,
#          '04240': 57,
#          '10601': 57,
#          '37212': 57,
#          '28277': 57,
#          '28078': 57,
#          '08054': 57,
#          '01742': 57,
#          '29407': 57,
#          '40205': 57,
#          '04101': 57,
#          '53227': 57,
#          '33431': 56,
#          '10591': 56,
#          '20902': 56,
#          '21202': 56,
#          '33155': 56,
#          '07724': 56,
#          '30106': 56,
#          '37204': 56,
#          '10941': 56,
#          '85306': 56,
#          '06611': 56,
#          '90720': 56,
#          '46250': 56,
#          '85037': 56,
#          '53233': 56,
#          '19004': 56,
#          '87102': 55,
#          '54703': 55,
#          '29506': 55,
#          '95608': 55,
#          '33146': 55,
#          '48236': 55,
#          '24501': 55,
#          '53211': 55,
#          '77339': 55,
#          '01201': 55,
#          '79761': 55,
#          '42101': 55,
#          '03060': 55,
#          '22102': 55,
#          '07112': 55,
#          '08034': 55,
#          '32701': 55,
#          '89102': 55,
#          '48126': 55,
#          '33770': 55,
#          '85308': 55,
#          '06457': 55,
#          '38301': 54,
#          '11772': 54,
#          '07083': 54,
#          '60007': 54,
#          '22801': 54,
#          '80122': 54,
#          '42303': 54,
#          '84112': 54,
#          '11725': 54,
#          '30076': 54,
#          '78701': 54,
#          '55422': 54,
#          '59405': 54,
#          '78746': 54,
#          '92705': 54,
#          '48084': 54,
#          '45459': 54,
#          '20774': 54,
#          '75503': 54,
#          '02720': 54,
#          '00907': 54,
#          '02301': 54,
#          '78236': 54,
#          '19087': 54,
#          '94801': 54,
#          '77008': 54,
#          '45440': 54,
#          '06518': 54,
#          '80228': 53,
#          '60045': 53,
#          '18045': 53,
#          '48532': 53,
#          '71301': 53,
#          '10604': 53,
#          '35249': 53,
#          '60048': 53,
#          '47714': 53,
#          '72903': 53,
#          '19803': 53,
#          '42003': 53,
#          '60463': 53,
#          '21229': 53,
#          '18840': 53,
#          '83642': 53,
#          '11234': 53,
#          '38305': 53,
#          '60187': 53,
#          '34667': 52,
#          '17402': 52,
#          '29201': 52,
#          '33912': 52,
#          '70072': 52,
#          '10901': 52,
#          '00961': 52,
#          '12901': 52,
#          '93901': 52,
#          '33407': 52,
#          '90024': 52,
#          '29401': 52,
#          '20770': 52,
#          '19718': 52,
#          '06851': 52,
#          '37909': 52,
#          '06052': 51,
#          '32940': 51,
#          '60134': 51,
#          '78404': 51,
#          '85719': 51,
#          '39401': 51,
#          '46123': 51,
#          '33952': 51,
#          '54401': 51,
#          '07701': 51,
#          '91790': 51,
#          '90242': 51,
#          '94117': 51,
#          '55417': 51,
#          '98026': 51,
#          '43082': 51,
#          '97220': 51,
#          '01702': 51,
#          '78130': 51,
#          '33063': 51,
#          '18711': 50,
#          '98108': 50,
#          '15601': 50,
#          '85008': 50,
#          '30165': 50,
#          '76504': 50,
#          '91767': 50,
#          '32514': 50,
#          '63703': 50,
#          '30078': 50,
#          '95204': 50,
#          '18702': 50,
#          '02062': 50,
#          '41042': 50,
#          '21218': 50,
#          '85741': 50,
#          '37620': 50,
#          '00674': 50,
#          '08003': 50,
#          '76022': 50,
#          '91307': 50,
#          '06824': 50,
#          '98383': 50,
#          '85704': 50,
#          '60031': 50,
#          '23116': 50,
#          '60616': 50,
#          '11901': 50,
#          '48066': 50,
#          '44710': 50,
#          '85364': 50,
#          '32250': 50,
#          '92056': 50,
#          '19102': 50,
#          '05403': 50,
#          '80033': 49,
#          '28562': 49,
#          '18510': 49,
#          ...})
